# %%
import pandas as pd 
import numpy as np

df = pd.read_csv('innings.csv')
df
# Out:
#         id  matchId  inningsNumber  runRate  overProgress  runs  wkts  \
# 0        1     3124              1     4.82          50.0   241     9
# 1        2     3124              2     3.95          47.2   187    10
# 2        3     3125              1     6.68          50.0   334     6
# 3        4     3125              2     3.26          40.1   131     9
# 4        5     3126              1     3.98          50.0   199    10
# ...    ...      ...            ...      ...           ...   ...   ...
# 2677  2678   101735              2     5.47          26.5   147    10
# 2678  2679   102844              1     4.33          49.1   213    10
# 2679  2680   102844              2     4.14          41.3   172    10
# 2680  2681   102109              1     6.76          50.0   338     6
# 2681  2682   102109              2     6.57          34.3   227    10
#
#       ballsFaced  fours  sixes  allOut  noBallRuns  wideRuns  byeRuns  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2682 entries, 0 to 2681
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             2682 non-null   int64
#  1   matchId        2682 non-null   int64
#  2   inningsNumber  2682 non-null   int64
#  3   runRate        2682 non-null   float64
#  4   overProgress   2682 non-null   float64
#  5   runs           2682 non-null   int64
#  6   wkts           2682 non-null   int64
#  7   ballsFaced     2682 non-null   int64
#  8   fours          2682 non-null   int64
#  9   sixes          2682 non-null   int64
#  10  allOut         2682 non-null   bool
#  11  noBallRuns     2682 non-null   int64
#  12  wideRuns       2682 non-null   int64
#  13  byeRuns        2682 non-null   int64
#  14  legByeRuns     2682 non-null   int64
#  15  penaltyRuns    2682 non-null   int64
#  16  battingTeamId  601 non-null    float64
#  17  bowlingTeamId  601 non-null    float64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# id                  0
# matchId             0
# inningsNumber       0
# runRate             0
# overProgress        0
# runs                0
# wkts                0
# ballsFaced          0
# fours               0
# sixes               0
# allOut              0
# noBallRuns          0
# wideRuns            0
# byeRuns             0
# legByeRuns          0
# penaltyRuns         0
# battingTeamId    2081
# bowlingTeamId    2081
# dtype: int64

# %%
df.drop(columns=['battingTeamId','bowlingTeamId'], inplace=True)

# %%
df
# Out:
#         id  matchId  inningsNumber  runRate  overProgress  runs  wkts  \
# 0        1     3124              1     4.82          50.0   241     9
# 1        2     3124              2     3.95          47.2   187    10
# 2        3     3125              1     6.68          50.0   334     6
# 3        4     3125              2     3.26          40.1   131     9
# 4        5     3126              1     3.98          50.0   199    10
# ...    ...      ...            ...      ...           ...   ...   ...
# 2677  2678   101735              2     5.47          26.5   147    10
# 2678  2679   102844              1     4.33          49.1   213    10
# 2679  2680   102844              2     4.14          41.3   172    10
# 2680  2681   102109              1     6.76          50.0   338     6
# 2681  2682   102109              2     6.57          34.3   227    10
#
#       ballsFaced  fours  sixes  allOut  noBallRuns  wideRuns  byeRuns  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# matchId          0
# inningsNumber    0
# runRate          0
# overProgress     0
# runs             0
# wkts             0
# ballsFaced       0
# fours            0
# sixes            0
# allOut           0
# noBallRuns       0
# wideRuns         0
# byeRuns          0
# legByeRuns       0
# penaltyRuns      0
# dtype: int64

# %%
df['allOut'].value_counts()
# Out:
# False    1689
# True      993
# Name: allOut, dtype: int64

# %%
df.tail()
# Out:
#         id  matchId  inningsNumber  runRate  overProgress  runs  wkts  \
# 2677  2678   101735              2     5.47          26.5   147    10
# 2678  2679   102844              1     4.33          49.1   213    10
# 2679  2680   102844              2     4.14          41.3   172    10
# 2680  2681   102109              1     6.76          50.0   338     6
# 2681  2682   102109              2     6.57          34.3   227    10
#
#       ballsFaced  fours  sixes  allOut  noBallRuns  wideRuns  byeRuns  \
# 2677         161     16      1    True           0         4        0
# 2678         295     12      4    True           0        20        0
# 2679         249     16      1    True           1         8        0
# 2680         300     32      7   False           0         9        0
# 2681         207     30      6    True           1         4        0
#
#       legByeRuns  penaltyRuns
# 2677           2            0
# 2678           1            0
# ...

# %%
df.drop(columns=['noBallRuns','wideRuns'], inplace=True)

# %%
df
# Out:
#         id  matchId  inningsNumber  runRate  overProgress  runs  wkts  \
# 0        1     3124              1     4.82          50.0   241     9
# 1        2     3124              2     3.95          47.2   187    10
# 2        3     3125              1     6.68          50.0   334     6
# 3        4     3125              2     3.26          40.1   131     9
# 4        5     3126              1     3.98          50.0   199    10
# ...    ...      ...            ...      ...           ...   ...   ...
# 2677  2678   101735              2     5.47          26.5   147    10
# 2678  2679   102844              1     4.33          49.1   213    10
# 2679  2680   102844              2     4.14          41.3   172    10
# 2680  2681   102109              1     6.76          50.0   338     6
# 2681  2682   102109              2     6.57          34.3   227    10
#
#       ballsFaced  fours  sixes  allOut  byeRuns  legByeRuns  penaltyRuns
# ...

# %%
df.std()
# Out:
# id                 774.371035
# matchId          38412.373645
# inningsNumber        0.500062
# runRate              1.174865
# overProgress         8.996007
# runs                70.897934
# wkts                 2.740889
# ballsFaced         112.282896
# fours                8.785216
# sixes                2.434082
# allOut               0.482961
# byeRuns              1.690977
# legByeRuns           2.794141
# penaltyRuns          0.360370
# dtype: float64

# %%
df.mean()
# Out:
# id                1341.500000
# matchId          26651.462342
# inningsNumber        1.494407
# runRate              5.275459
# overProgress        43.772110
# runs               231.857196
# wkts                 7.419090
# ballsFaced          58.701342
# fours                4.330723
# sixes                0.953766
# allOut               0.370246
# byeRuns              0.911633
# legByeRuns           3.388516
# penaltyRuns          0.026100
# dtype: float64

# %%
df.describe()
# Out:
#                 id        matchId  inningsNumber      runRate  overProgress  \
# count  2682.000000    2682.000000    2682.000000  2682.000000   2682.000000
# mean   1341.500000   26651.462342       1.494407     5.275459     43.772110
# std     774.371035   38412.373645       0.500062     1.174865      8.996007
# min       1.000000     543.000000       1.000000     2.370000      0.400000
# 25%     671.250000    3166.000000       1.000000     4.442500     41.000000
# 50%    1341.500000    6896.000000       1.000000     5.210000     48.200000
# 75%    2011.750000   31750.000000       2.000000     6.000000     50.000000
# max    2682.000000  102980.000000       2.000000    14.160000     50.000000
#
#               runs         wkts   ballsFaced        fours        sixes  \
# count  2682.000000  2682.000000  2682.000000  2682.000000  2682.000000
# mean    231.857196     7.419090    58.701342     4.330723     0.953766
# ...

# %%
df.to_csv('cleaned_innings.csv', index=False)

# %%
df
# Out:
#         id  matchId  inningsNumber  runRate  overProgress  runs  wkts  \
# 0        1     3124              1     4.82          50.0   241     9
# 1        2     3124              2     3.95          47.2   187    10
# 2        3     3125              1     6.68          50.0   334     6
# 3        4     3125              2     3.26          40.1   131     9
# 4        5     3126              1     3.98          50.0   199    10
# ...    ...      ...            ...      ...           ...   ...   ...
# 2677  2678   101735              2     5.47          26.5   147    10
# 2678  2679   102844              1     4.33          49.1   213    10
# 2679  2680   102844              2     4.14          41.3   172    10
# 2680  2681   102109              1     6.76          50.0   338     6
# 2681  2682   102109              2     6.57          34.3   227    10
#
#       ballsFaced  fours  sixes  allOut  byeRuns  legByeRuns  penaltyRuns
# ...
