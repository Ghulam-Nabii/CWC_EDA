# %%
import pandas as pd 
import numpy as np

df = pd.read_csv('players.csv')
df
# Out:
#            id               fullName          shortName nationality  \
# 0        2065          Rick McCosker        RB McCosker  Australian
# 1        2114            Alan Turner           A Turner  Australian
# 2        2083          Greg Chappell         G Chappell  Australian
# 3        2115           Jeff Thomson          J Thomson  Australian
# 4        2020           Ian Chappell         I Chappell  Australian
# ...       ...                    ...                ...         ...
# 28906    1527           Nikhil Dutta            N Dutta          CA
# 28907  102982           Pargat Singh           PS Singh          CA
# 28908   13716      Ravinderpal Singh  Ravinderpal Singh          CA
# 28909    2770         Saad Bin Zafar     Saad Bin Zafar          CA
# 28910  102866  Srimantha Wijeyeratne     SA Wijeyeratne          CA
#
#       dateOfBirth  rightArmedBowl  rightHandedBat bowlingStyle  teamId
# 0      1946-12-11           False            True          NaN    2808
# ...

# %%
df.tail()
# Out:
#            id               fullName          shortName nationality  \
# 28906    1527           Nikhil Dutta            N Dutta          CA
# 28907  102982           Pargat Singh           PS Singh          CA
# 28908   13716      Ravinderpal Singh  Ravinderpal Singh          CA
# 28909    2770         Saad Bin Zafar     Saad Bin Zafar          CA
# 28910  102866  Srimantha Wijeyeratne     SA Wijeyeratne          CA
#
#       dateOfBirth  rightArmedBowl  rightHandedBat  teamId
# 28906  1994-10-13            True            True      66
# 28907  1992-04-13            True            True      66
# 28908  1988-10-14            True            True      66
# 28909  1986-11-10           False           False      66
# 28910  1989-06-03            True            True      66

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28911 entries, 0 to 28910
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              28911 non-null  int64
#  1   fullName        28911 non-null  object
#  2   shortName       28911 non-null  object
#  3   nationality     28249 non-null  object
#  4   dateOfBirth     28349 non-null  object
#  5   rightArmedBowl  28911 non-null  bool
#  6   rightHandedBat  28911 non-null  bool
#  7   bowlingStyle    18328 non-null  object
#  8   teamId          28911 non-null  int64
# dtypes: bool(2), int64(2), object(5)
# memory usage: 1.6+ MB

# %%
df.isnull().sum()
# Out:
# id                    0
# fullName              0
# shortName             0
# nationality         662
# dateOfBirth         562
# rightArmedBowl        0
# rightHandedBat        0
# bowlingStyle      10583
# teamId                0
# dtype: int64

# %%
df = df.dropna(subset=['nationality', 'dateOfBirth'])

# %%
df
# Out:
#            id               fullName          shortName nationality  \
# 0        2065          Rick McCosker        RB McCosker  Australian
# 1        2114            Alan Turner           A Turner  Australian
# 2        2083          Greg Chappell         G Chappell  Australian
# 3        2115           Jeff Thomson          J Thomson  Australian
# 4        2020           Ian Chappell         I Chappell  Australian
# ...       ...                    ...                ...         ...
# 28906    1527           Nikhil Dutta            N Dutta          CA
# 28907  102982           Pargat Singh           PS Singh          CA
# 28908   13716      Ravinderpal Singh  Ravinderpal Singh          CA
# 28909    2770         Saad Bin Zafar     Saad Bin Zafar          CA
# 28910  102866  Srimantha Wijeyeratne     SA Wijeyeratne          CA
#
#       dateOfBirth  rightArmedBowl  rightHandedBat bowlingStyle  teamId
# 0      1946-12-11           False            True          NaN    2808
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# fullName             0
# shortName            0
# nationality          0
# dateOfBirth          0
# rightArmedBowl       0
# rightHandedBat       0
# bowlingStyle      9974
# teamId               0
# dtype: int64

# %%
df.dtypes
# Out:
# id                 int64
# fullName          object
# shortName         object
# nationality       object
# dateOfBirth       object
# rightArmedBowl      bool
# rightHandedBat      bool
# bowlingStyle      object
# teamId             int64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns='bowlingStyle', inplace=True)

# Displaying the DataFrame after dropping the column
print("DataFrame after dropping 'passengers' column:")
df
# Out:
# DataFrame after dropping 'passengers' column:
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_77451/342255546.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns='bowlingStyle', inplace=True)
#            id               fullName          shortName nationality  \
# 0        2065          Rick McCosker        RB McCosker  Australian
# 1        2114            Alan Turner           A Turner  Australian
# 2        2083          Greg Chappell         G Chappell  Australian
# 3        2115           Jeff Thomson          J Thomson  Australian
# 4        2020           Ian Chappell         I Chappell  Australian
# ...       ...                    ...                ...         ...
# 28906    1527           Nikhil Dutta            N Dutta          CA
# ...

# %%
df['dateOfBirth'] = pd.to_datetime(df['dateOfBirth'])
# Out:
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_77451/1683126930.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dateOfBirth'] = pd.to_datetime(df['dateOfBirth'])

# %%
df.dtypes
# Out:
# id                         int64
# fullName                  object
# shortName                 object
# nationality               object
# dateOfBirth       datetime64[ns]
# rightArmedBowl              bool
# rightHandedBat              bool
# teamId                     int64
# dtype: object

# %%
df['nationality'] = df['nationality'].replace('CA', 'Canadian')
df
# Out:
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_77451/3859180548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nationality'] = df['nationality'].replace('CA', 'Canadian')
#            id               fullName          shortName nationality  \
# 0        2065          Rick McCosker        RB McCosker  Australian
# 1        2114            Alan Turner           A Turner  Australian
# 2        2083          Greg Chappell         G Chappell  Australian
# 3        2115           Jeff Thomson          J Thomson  Australian
# 4        2020           Ian Chappell         I Chappell  Australian
# ...       ...                    ...                ...         ...
# ...

# %%
df['nationality'].value_counts()
# Out:
# Indian           2851
# Sri Lankan       2783
# Australian       2593
# Pakistani        2483
# English          2478
# South African    2309
# New Zealander    2303
# West Indian      2074
# Zimbabwean       1933
# Bangladeshi      1554
# Irish            1073
# Afghan            953
# Scottish          424
# Kenyan            365
# Emirati           340
# Dutch             304
# Papuan            189
# Namibian          157
# Canadian          115
# Nepalese          110
# Omani             109
# American          108
# Hong Konger        99
# Barbados           92
# Trinidadian        81
# Jamaican           66
# Guyanan            63
# Bermudian          31
# Antiguan           25
# Dominican          22
# Zambian            21
# Egyptian           20
# Nevis              18
# JE                 11
# SCO                10
# ENG                10
# PG                  9
# BD                  8
# IN                  7
# NP                  7
# PK                  7
# ...

# %%
df['nationality'] = df['nationality'].replace('JE', 'Jersey')
# Out:
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_77451/1388426123.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nationality'] = df['nationality'].replace('JE', 'Jersey')

# %%
df['nationality'] = df['nationality'].replace('SCO', 'Scottish')
# Out:
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_77451/2883326853.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nationality'] = df['nationality'].replace('SCO', 'Scottish')

# %%
df['nationality'] = df['nationality'].replace('ENG', 'English')
# Out:
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_77451/2877826400.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nationality'] = df['nationality'].replace('ENG', 'English')

# %%
df['nationality'] = df['nationality'].replace('PG', 'Papuans')
# Out:
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_77451/288887266.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nationality'] = df['nationality'].replace('PG', 'Papuans')

# %%
df['nationality'] = df['nationality'].replace('BD', 'Bangladeshi')
# Out:
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_77451/571708352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nationality'] = df['nationality'].replace('BD', 'Bangladeshi')

# %%
df['nationality'] = df['nationality'].replace('IN', 'Indian')
# Out:
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_77451/45193996.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nationality'] = df['nationality'].replace('IN', 'Indian')

# %%
df['nationality'] = df['nationality'].replace('NP', 'Nepali')
# Out:
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_77451/3406907827.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nationality'] = df['nationality'].replace('NP', 'Nepali')

# %%
df['nationality'] = df['nationality'].replace('PK', 'Pakistani')
# Out:
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_77451/1821130889.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nationality'] = df['nationality'].replace('PK', 'Pakistani')

# %%
df['nationality'].value_counts()
# Out:
# Indian           2858
# Sri Lankan       2783
# Australian       2593
# Pakistani        2490
# English          2488
# South African    2309
# New Zealander    2303
# West Indian      2074
# Zimbabwean       1933
# Bangladeshi      1562
# Irish            1073
# Afghan            953
# Scottish          434
# Kenyan            365
# Emirati           340
# Dutch             304
# Papuan            189
# Namibian          157
# Canadian          115
# Nepalese          110
# Omani             109
# American          108
# Hong Konger        99
# Barbados           92
# Trinidadian        81
# Jamaican           66
# Guyanan            63
# Bermudian          31
# Antiguan           25
# Dominican          22
# Zambian            21
# Egyptian           20
# Nevis              18
# Jersey             11
# Papuans             9
# Nepali              7
# St Kitts            6
# Ugandan             6
# St Vincent          6
# St Lucian           5
# Grenadan            4
# ...

# %%
df.drop(columns='shortName', inplace=True)
# Out:
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_77451/1081845087.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns='shortName', inplace=True)

# %%
df
# Out:
#            id               fullName nationality dateOfBirth  rightArmedBowl  \
# 0        2065          Rick McCosker  Australian  1946-12-11           False
# 1        2114            Alan Turner  Australian  1950-07-23           False
# 2        2083          Greg Chappell  Australian  1948-08-07            True
# 3        2115           Jeff Thomson  Australian  1950-08-16            True
# 4        2020           Ian Chappell  Australian  1943-09-26            True
# ...       ...                    ...         ...         ...             ...
# 28906    1527           Nikhil Dutta    Canadian  1994-10-13            True
# 28907  102982           Pargat Singh    Canadian  1992-04-13            True
# 28908   13716      Ravinderpal Singh    Canadian  1988-10-14            True
# 28909    2770         Saad Bin Zafar    Canadian  1986-11-10           False
# 28910  102866  Srimantha Wijeyeratne    Canadian  1989-06-03            True
#
#        rightHandedBat  teamId
# ...

# %%
df.rename(columns={'fullName': 'name'}, inplace=True)
# Out:
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_77451/2607221382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'fullName': 'name'}, inplace=True)

# %%
df['nationality'].value_counts()
# Out:
# Indian           2858
# Sri Lankan       2783
# Australian       2593
# Pakistani        2490
# English          2488
# South African    2309
# New Zealander    2303
# West Indian      2074
# Zimbabwean       1933
# Bangladeshi      1562
# Irish            1073
# Afghan            953
# Scottish          434
# Kenyan            365
# Emirati           340
# Dutch             304
# Papuan            189
# Namibian          157
# Canadian          115
# Nepalese          110
# Omani             109
# American          108
# Hong Konger        99
# Barbados           92
# Trinidadian        81
# Jamaican           66
# Guyanan            63
# Bermudian          31
# Antiguan           25
# Dominican          22
# Zambian            21
# Egyptian           20
# Nevis              18
# Jersey             11
# Papuans             9
# Nepali              7
# St Kitts            6
# Ugandan             6
# St Vincent          6
# St Lucian           5
# Grenadan            4
# ...

# %%
df['rightHandedBat'].value_counts()
# Out:
# True     20980
# False     7267
# Name: rightHandedBat, dtype: int64

# %%
df['rightArmedBowl'].value_counts()
# Out:
# True     16972
# False    11275
# Name: rightArmedBowl, dtype: int64

# %%
df.to_csv('cleaned_players.csv', index=False)

# %%
df
# Out:
#            id                   name nationality dateOfBirth  rightArmedBowl  \
# 0        2065          Rick McCosker  Australian  1946-12-11           False
# 1        2114            Alan Turner  Australian  1950-07-23           False
# 2        2083          Greg Chappell  Australian  1948-08-07            True
# 3        2115           Jeff Thomson  Australian  1950-08-16            True
# 4        2020           Ian Chappell  Australian  1943-09-26            True
# ...       ...                    ...         ...         ...             ...
# 28906    1527           Nikhil Dutta    Canadian  1994-10-13            True
# 28907  102982           Pargat Singh    Canadian  1992-04-13            True
# 28908   13716      Ravinderpal Singh    Canadian  1988-10-14            True
# 28909    2770         Saad Bin Zafar    Canadian  1986-11-10           False
# 28910  102866  Srimantha Wijeyeratne    Canadian  1989-06-03            True
#
#        rightHandedBat  teamId
# ...

# %%
df.rename(columns={'name': 'Player Name'}, inplace=True)
# Out:
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_77451/2560367137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'name': 'Player Name'}, inplace=True)

# %%
df
# Out:
#            id            Player Name nationality dateOfBirth  rightArmedBowl  \
# 0        2065          Rick McCosker  Australian  1946-12-11           False
# 1        2114            Alan Turner  Australian  1950-07-23           False
# 2        2083          Greg Chappell  Australian  1948-08-07            True
# 3        2115           Jeff Thomson  Australian  1950-08-16            True
# 4        2020           Ian Chappell  Australian  1943-09-26            True
# ...       ...                    ...         ...         ...             ...
# 28906    1527           Nikhil Dutta    Canadian  1994-10-13            True
# 28907  102982           Pargat Singh    Canadian  1992-04-13            True
# 28908   13716      Ravinderpal Singh    Canadian  1988-10-14            True
# 28909    2770         Saad Bin Zafar    Canadian  1986-11-10           False
# 28910  102866  Srimantha Wijeyeratne    Canadian  1989-06-03            True
#
#        rightHandedBat  teamId
# ...

# %%
df.to_csv('cleaned_players.csv', index=False)
