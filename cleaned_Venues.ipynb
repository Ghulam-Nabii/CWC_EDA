# %%
import pandas as pd 
import numpy as np

df = pd.read_csv('venues.csv')
df
# Out:
#          id                                           fullName  \
# 0         1                          M. A. Chidambaram Stadium
# 1         2                                       Eden Gardens
# 2         3                             Sawai Mansingh Stadium
# 3         4                                   Wankhede Stadium
# 4         5                             M. Chinnaswamy Stadium
# ..      ...                                                ...
# 188  100165  Shaheed Veer Narayan Singh International Crick...
# 189  100178                              YS Raja Reddy Stadium
# 190  100187                         United Cricket Club Ground
# 191  100194    Mahinda Rajapaksa International Cricket Stadium
# 192  100236                             Takashinga Sports Club
#
#                   shortName         city country
# 0               Chidambaram      Chennai   India
# 1              Eden Gardens      Kolkata   India
# 2    Sawai Mansingh Stadium       Jaipur   India
# ...

# %%
df.drop('shortName',inplace = True,axis = 1)

# %%
df
# Out:
#          id                                           fullName         city  \
# 0         1                          M. A. Chidambaram Stadium      Chennai
# 1         2                                       Eden Gardens      Kolkata
# 2         3                             Sawai Mansingh Stadium       Jaipur
# 3         4                                   Wankhede Stadium       Mumbai
# 4         5                             M. Chinnaswamy Stadium    Bengaluru
# ..      ...                                                ...          ...
# 188  100165  Shaheed Veer Narayan Singh International Crick...          NaN
# 189  100178                              YS Raja Reddy Stadium       Kadapa
# 190  100187                         United Cricket Club Ground          NaN
# 191  100194    Mahinda Rajapaksa International Cricket Stadium  Sooriyawewa
# 192  100236                             Takashinga Sports Club          NaN
#
#     country
# 0     India
# 1     India
# 2     India
# ...

# %%
df.rename(columns={'fullName': 'name'}, inplace=True)

# %%
df
# Out:
#          id                                               name         city  \
# 0         1                          M. A. Chidambaram Stadium      Chennai
# 1         2                                       Eden Gardens      Kolkata
# 2         3                             Sawai Mansingh Stadium       Jaipur
# 3         4                                   Wankhede Stadium       Mumbai
# 4         5                             M. Chinnaswamy Stadium    Bengaluru
# ..      ...                                                ...          ...
# 188  100165  Shaheed Veer Narayan Singh International Crick...          NaN
# 189  100178                              YS Raja Reddy Stadium       Kadapa
# 190  100187                         United Cricket Club Ground          NaN
# 191  100194    Mahinda Rajapaksa International Cricket Stadium  Sooriyawewa
# 192  100236                             Takashinga Sports Club          NaN
#
#     country
# 0     India
# 1     India
# 2     India
# ...

# %%
df.isnull().sum()
# Out:
# id          0
# name        0
# city        8
# country    20
# dtype: int64

# %%
df = df.dropna()

# %%
df
# Out:
#        id                                               name       city  \
# 0       1                          M. A. Chidambaram Stadium    Chennai
# 1       2                                       Eden Gardens    Kolkata
# 2       3                             Sawai Mansingh Stadium     Jaipur
# 3       4                                   Wankhede Stadium     Mumbai
# 4       5                             M. Chinnaswamy Stadium  Bengaluru
# ..    ...                                                ...        ...
# 168   588                        Oman Cricket Academy Ground  Al Amerat
# 169   942                         Al Amerat Cricket Ground 2  Al Amerat
# 170  1010  Tribhuvan University International Cricket Ground   Kirtipur
# 171  1013                                          Wanderers   Windhoek
# 172  1057        West End Park International Cricket Stadium       Doha
#
#      country
# 0      India
# 1      India
# 2      India
# 3      India
# 4      India
# ..       ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173 entries, 0 to 172
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       173 non-null    int64
#  1   name     173 non-null    object
#  2   city     173 non-null    object
#  3   country  173 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 6.8+ KB

# %%
df['country'].value_counts()
# Out:
# India                42
# England              19
# Australia            16
# New Zealand          16
# South Africa         12
# West Indies           8
# Pakistan              8
# Sri Lanka             7
# Ireland               6
# Bangladesh            5
# Oman                  4
# Namibia               4
# Netherlands           4
# Zimbabwe              4
# UAE                   4
# Scotland              3
# Northern Ireland      2
# Wales                 2
# Malaysia              1
# Kenya                 1
# Papua New Guinea      1
# USA                   1
# Trinidad & Tobago     1
# Nepal                 1
# Qatar                 1
# Name: country, dtype: int64

# %%
df.to_csv('cleaned_venues.csv', index=False)

# %%
df
# Out:
#        id                                               name       city  \
# 0       1                          M. A. Chidambaram Stadium    Chennai
# 1       2                                       Eden Gardens    Kolkata
# 2       3                             Sawai Mansingh Stadium     Jaipur
# 3       4                                   Wankhede Stadium     Mumbai
# 4       5                             M. Chinnaswamy Stadium  Bengaluru
# ..    ...                                                ...        ...
# 168   588                        Oman Cricket Academy Ground  Al Amerat
# 169   942                         Al Amerat Cricket Ground 2  Al Amerat
# 170  1010  Tribhuvan University International Cricket Ground   Kirtipur
# 171  1013                                          Wanderers   Windhoek
# 172  1057        West End Park International Cricket Stadium       Doha
#
#      country
# 0      India
# 1      India
# 2      India
# 3      India
# 4      India
# ..       ...
# ...

# %%
df.rename(columns={'name': 'Stadium Name'}, inplace=True)
# Out:
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_77468/1206098764.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'name': 'Stadium Name'}, inplace=True)

# %%
df
# Out:
#        id                                       Stadium Name       city  \
# 0       1                          M. A. Chidambaram Stadium    Chennai
# 1       2                                       Eden Gardens    Kolkata
# 2       3                             Sawai Mansingh Stadium     Jaipur
# 3       4                                   Wankhede Stadium     Mumbai
# 4       5                             M. Chinnaswamy Stadium  Bengaluru
# ..    ...                                                ...        ...
# 168   588                        Oman Cricket Academy Ground  Al Amerat
# 169   942                         Al Amerat Cricket Ground 2  Al Amerat
# 170  1010  Tribhuvan University International Cricket Ground   Kirtipur
# 171  1013                                          Wanderers   Windhoek
# 172  1057        West End Park International Cricket Stadium       Doha
#
#      country
# 0      India
# 1      India
# 2      India
# 3      India
# 4      India
# ..       ...
# ...

# %%
df.to_csv('cleaned_venues.csv', index=False)
